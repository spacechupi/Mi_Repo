# %% [markdown]
# ### Aptitudes de Data Scientist
# > #### Lo más importante
# > * Matemáticas
# > * Programación
# > * SQL
# > * Python                                          ![Python.png](attachment:Python.png)
# >
# > Otro tema importante es el _Business Intelligence_.
# >
# > Si tienes dudas, pudes escribirme a: rafael@thebridgeschool.es
# >
# > En esta página se aprende mucho de machine learning: [pagina con ML](https://www.kaggle.com/)
